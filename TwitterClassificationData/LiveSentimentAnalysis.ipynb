# %%
# General:
import tweepy           # To consume Twitter's API
import pandas as pd     # To handle data
import numpy as np      # For number computing
import csv
# For plotting and visualization:
from IPython.display import display
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# Twitter App access keys for @user

# Consume:
CONSUMER_KEY    = '8HYjU302JpHFIW7IyFmOckUWc'
CONSUMER_SECRET = 'cGKAjfTZEVDP1MtgeZCb2buqeDGYNFz9LXkrlFcB1DfDp6zdb0'

# Access:
ACCESS_TOKEN  = '1233046286-2gCux1d9eXLAP84gOZuaRrbbgKrem7NI54XVbOm'
ACCESS_SECRET = 'BsE3zqAjJq7ZKaBACs5bYoa8KEvNxEH7I3ZD5SZvTHhlX'

RECENT_TWEETS = 10

results = []

# API's setup:
def twitter_setup():
    """
    Utility function to setup the Twitter's API
    with our access keys provided.
    """
    # Authentication and access using keys:
    auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
    auth.set_access_token(ACCESS_TOKEN, ACCESS_SECRET)

    # Return API with authentication:
    api = tweepy.API(auth)
    return api


# store to dataframe
def tweets_df(results):
    id_list = [tweet.id for tweet  in results]
    data_set = pd.DataFrame(id_list, columns = ["id"])
    
    data_set["text"] = [tweet.text for tweet in results]
    data_set["created_at"] = [tweet.created_at for tweet in results]
    data_set["retweet_count"] = [tweet.retweet_count for tweet in results]
    data_set["user_screen_name"] = [tweet.author.screen_name for tweet in results]
    data_set["user_followers_count"] = [tweet.author.followers_count for tweet in results]
    data_set["user_location"] = [tweet.author.location for tweet in results]
    data_set["Hashtags"] = [tweet.entities.get('hashtags') for tweet in results]
    return data_set

# We create an extractor object:
extractor = twitter_setup()

# We create a tweet list as follows:
tweets = tweepy.Cursor(extractor.search,q="#HappyNewYear2019",count=1000000,lang="en",since="2018-12-31").items(RECENT_TWEETS)

# #===================================================
# # Download and save
# # Open/Create a file to append data
# csvFile = open('ua.csv', 'a')
# #Use csv Writer
# csvWriter = csv.writer(csvFile)

# for tweet in tweepy.Cursor(extractor.search,q="#HappyNewYear2019",count=1000000,lang="en",since="2018-12-31").items():
#     print (tweet.created_at, tweet.text)
#     csvWriter.writerow([tweet.created_at, tweet.text.encode('utf-8')])
# #===================================================

# We print the most recent 5 tweets:
print("{0} recent tweets:\n".format(RECENT_TWEETS))
for tweet in tweets:
    results.append(tweet)
    
print("Number of tweets extracted: {}.\n".format(len(results)))

print(results)
data_set = tweets_df(results)
display(data_set)

# # Remove tweets with duplicate text

# text = data_set["text"]

# for i in range(0,len(text)):
#     txt = ' '.join(word for word in text[i] .split() if not word.startswith('https:'))
#     data_set.set_value(i, 'text2', txt)
    
# data_set.drop_duplicates('text2', inplace=True)
# data_set.reset_index(drop = True, inplace=True)
# data_set.drop('text', axis = 1, inplace = True)
# data_set.rename(columns={'text2': 'text'}, inplace=True)

# text = data_set["text"]

# for i in range(0,len(text)):
#     textB = TextBlob(text[i])
#     sentiment = textB.sentiment.polarity
#     data_set.set_value(i, 'Sentiment',sentiment)
#     if sentiment <0.00:
#         SentimentClass = 'Negative'
#         data_set.set_value(i, 'SentimentClass', SentimentClass )
#     elif sentiment >0.00:
#         SentimentClass = 'Positive'
#         data_set.set_value(i, 'SentimentClass', SentimentClass )
#     else:
#         SentimentClass = 'Neutral'
#         data_set.set_value(i, 'SentimentClass', SentimentClass )
# data_set.to_csv("HappyNewYearAnalysis.csv")

# Htag_df = pd.DataFrame()
# j = 0

# for tweet in range(0,len(results)):
#     hashtag = results[tweet].entities.get('hashtags')
#     for i in range(0,len(hashtag)):
#         Htag = hashtag[i]['text'] 
#         Htag_df.set_value(j, 'Hashtag',Htag)
#         j = j+1
# Out:
# 10 recent tweets:
#
# Number of tweets extracted: 10.
#
# [Status(_api=<tweepy.api.API object at 0x7efbbbaa0978>, _json={'created_at': 'Mon Dec 31 03:05:18 +0000 2018', 'id': 1079574186543251456, 'id_str': '1079574186543251456', 'text': 'RT @murugaramu_kkl: #HappyNewYear2019 \nWishes from #PettayilViswasam team 🎉🎊🎈✨🎈🎊🎉 https://t.co/oc1oAUZz9D', 'truncated': False, 'entities': {'hashtags': [{'text': 'HappyNewYear2019', 'indices': [20, 37]}, {'text': 'PettayilViswasam', 'indices': [51, 68]}], 'symbols': [], 'user_mentions': [{'screen_name': 'murugaramu_kkl', 'name': 'MuRuGaRaMu KaRaIkAL', 'id': 2183482843, 'id_str': '2183482843', 'indices': [3, 18]}], 'urls': [], 'media': [{'id': 1079566350442524672, 'id_str': '1079566350442524672', 'indices': [82, 105], 'media_url': 'http://pbs.twimg.com/media/Dvtj4D2XcAAGVnn.jpg', 'media_url_https': 'https://pbs.twimg.com/media/Dvtj4D2XcAAGVnn.jpg', 'url': 'https://t.co/oc1oAUZz9D', 'display_url': 'pic.twitter.com/oc1oAUZz9D', 'expanded_url': 'https://twitter.com/murugaramu_kkl/status/1079566379685167105/photo/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'small': {'w': 475, 'h': 680, 'resize': 'fit'}, 'medium': {'w': 839, 'h': 1200, 'resize': 'fit'}, 'large': {'w': 1432, 'h': 2048, 'resize': 'fit'}}, 'source_status_id': 1079566379685167105, 'source_status_id_str': '1079566379685167105', 'source_user_id': 2183482843, 'source_user_id_str': '2183482843'}]}, 'extended_entities': {'media': [{'id': 1079566350442524672, 'id_str': '1079566350442524672', 'indices': [82, 105], 'media_url': 'http://pbs.twimg.com/media/Dvtj4D2XcAAGVnn.jpg', 'media_url_https': 'https://pbs.twimg.com/media/Dvtj4D2XcAAGVnn.jpg', 'url': 'https://t.co/oc1oAUZz9D', 'display_url': 'pic.twitter.com/oc1oAUZz9D', 'expanded_url': 'https://twitter.com/murugaramu_kkl/status/1079566379685167105/photo/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'small': {'w': 475, 'h': 680, 'resize': 'fit'}, 'medium': {'w': 839, 'h': 1200, 'resize': 'fit'}, 'large': {'w': 1432, 'h': 2048, 'resize': 'fit'}}, 'source_status_id': 1079566379685167105, 'source_status_id_str': '1079566379685167105', 'source_user_id': 2183482843, 'source_user_id_str': '2183482843'}, {'id': 1079566367379152896, 'id_str': '1079566367379152896', 'indices': [82, 105], 'media_url': 'http://pbs.twimg.com/media/Dvtj5C8X4AALbTz.jpg', 'media_url_https': 'https://pbs.twimg.com/media/Dvtj5C8X4AALbTz.jpg', 'url': 'https://t.co/oc1oAUZz9D', 'display_url': 'pic.twitter.com/oc1oAUZz9D', 'expanded_url': 'https://twitter.com/murugaramu_kkl/status/1079566379685167105/photo/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'small': {'w': 440, 'h': 680, 'resize': 'fit'}, 'large': {'w': 895, 'h': 1383, 'resize': 'fit'}, 'medium': {'w': 777, 'h': 1200, 'resize': 'fit'}}, 'source_status_id': 1079566379685167105, 'source_status_id_str': '1079566379685167105', 'source_user_id': 2183482843, 'source_user_id_str': '2183482843'}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 469382759, 'id_str': '469382759', 'name': 'gokul s y', 'screen_name': 'gokulsy', 'location': 'bangalore', 'description': "i'm an engineering student pursuing in university visveshvaraya college of engineering, Bangalore.", 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 159, 'friends_count': 1446, 'listed_count': 21, 'created_at': 'Fri Jan 20 14:55:24 +0000 2012', 'favourites_count': 47187, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 48071, 'lang': 'en', 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_ ...
#                     id                                               text  \
# 0  1079574186543251456  RT @murugaramu_kkl: #HappyNewYear2019 \nWishes...
# 1  1079574172827828225  RT @loveGoldenHeart: @Sky13861654 @pratoshnive...
# 2  1079574167379308544  RT @BSNLCorporate: #BSNL is pleased to announc...
# 3  1079574158860795907  RT @SixBrownChicks: #HappyNewYear2019 May all ...
# 4  1079574136433844225  RT @SixBrownChicks: #HappyNewYear2019 May all ...
# 5  1079574078149648384  Saying goodbye to 2018, and welcoming 2019. #H...
# 6  1079574069924773888  RT @AsennaWealth: Isn't it ironic that the lea...
# 7  1079574068142104576  "I release all #feelings of\nlack and grateful...
# 8  1079574023330095104  RT @TFC_mass: Opened NewsPaper &amp; Found Our...
# 9  1079574006649573376  RT @giantleap4geeks: It's #SundayFunday that m...
#
#            created_at  retweet_count user_screen_name  user_followers_count  \
# 0 2018-12-31 03:05:18              3          gokulsy                   159
# 1 2018-12-31 03:05:14              1  loveGoldenHeart                 19426
# 2 2018-12-31 03:05:13             43  dharmen78520207                    22
# 3 2018-12-31 03:05:11              9   Clear_Destiny_                  1192
# 4 2018-12-31 03:05:06              2   Clear_Destiny_                  1192
# 5 2018-12-31 03:04:52              0      micoxtorres                   268
# 6 2018-12-31 03:04:50             15          SetonTM                   294
# 7 2018-12-31 03:04:50              0      media786786                  2939
# 8 2018-12-31 03:04:39             56     Dhakshna2000                    88
# 9 2018-12-31 03:04:35              4   BendYourEarPod                  1121
#
#                   user_location  \
# 0                     bangalore
# 1               🇺🇸United States
# 2
# 3  Living & Thriving Abundantly
# 4  Living & Thriving Abundantly
# 5
# 6                  AroundTheWay
# 7       Calicut/Chennai, India.
# 8
# 9                   Orlando, FL
#
#                                             Hashtags
# 0  [{'text': 'HappyNewYear2019', 'indices': [20, ...
# 1                                                 []
# 2  [{'text': 'BSNL', 'indices': [19, 24]}, {'text...
# 3  [{'text': 'HappyNewYear2019', 'indices': [20, ...
# 4  [{'text': 'HappyNewYear2019', 'indices': [20, ...
# 5  [{'text': 'HappyNewYear2019', 'indices': [44, ...
# 6                                                 []
# 7  [{'text': 'feelings', 'indices': [15, 24]}, {'...
# 8  [{'text': 'Thala', 'indices': [47, 53]}, {'tex...
# 9  [{'text': 'SundayFunday', 'indices': [26, 39]}...
